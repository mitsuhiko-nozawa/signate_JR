# %%
import pandas as pd

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
train_df[self.name] = train_df.groupby(["date", "trainNo"])["id"].transform("count")
# Out:
# 0          37
# 1          37
# 2          37
# 3          37
# 4          37
#            ..
# 1488880    22
# 1488881    22
# 1488882    22
# 1488883    22
# 1488884    22
# Name: id, Length: 1488885, dtype: int64
