# %%
import numpy as np
import pandas as pd
import os
import os.path as osp
import glob
from google.cloud import storage

# %%
PROJECT_ID = 'signateJR2020'
BUCKET_NAME = 'signate-jr2020'

os.environ["GCLOUD_PROJECT"] = PROJECT_ID
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "../signateJR2020-d11d5341dabe.json"
storage_client = storage.Client(project=PROJECT_ID)

blobs = storage_client.list_blobs(BUCKET_NAME) # storageのディレクトリ
# Out:
# artifacts/
# mlruns/

# %%
files = [f for f in glob.glob(osp.join("../experiments/exp_001/", "mlruns", "**"), recursive=True)]
files_in_bucket = [f.name for f in storage_client.list_blobs(BUCKET_NAME)]
bucket = storage_client.get_bucket(BUCKET_NAME)

# %%
import pprint
pprint.pprint(files_in_bucket)
# Out:
# ['artifacts/', 'mlruns/']

# %%
bucket.blob(files[0])
# Out:
# <Blob: signate-jr2020, ../experiments/exp_001/mlruns/, None>

# %%
#試しにupload
blob = bucket.blob("temp")
blob.upload_from_filename("temp")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-19-4531506e4974> in <module>
#       1 #試しにupload
#       2 blob = bucket.blob("temp")
# ----> 3 blob.upload_from_filename("temp")
#
# /opt/anaconda3/envs/ML/lib/python3.6/site-packages/google/cloud/storage/blob.py in upload_from_filename(self, filename, content_type, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum)
#    2456         content_type = self._get_content_type(content_type, filename=filename)
#    2457
# -> 2458         with open(filename, "rb") as file_obj:
#    2459             total_bytes = os.fstat(file_obj.fileno()).st_size
#    2460             self.upload_from_file(
#
# IsADirectoryError: [Errno 21] Is a directory: 'temp'

# %%
for f in files:
    try:
        if f not in files_in_bucket:
            blob = bucket.blob(f)
            blob.upload_from_filename(f.replace(self.WORK_DIR, ""))
    except:
        pass
