# %%
import pandas as pd
from datetime import date, timedelta

today = date.today()
date_time = []
for i in range(1000):
    for _ in range(1000):
        date_time.append(today + timedelta(days = i))
df = pd.DataFrame({
    'datetime': date_time
})

print(df.head())
# Out:
#      datetime
# 0  2020-12-09
# 1  2020-12-09
# 2  2020-12-09
# 3  2020-12-09
# 4  2020-12-09

# %%
import time
import logging
import jpholiday
from contextlib import contextmanager
@contextmanager
def timer(name, logger=None, level=logging.DEBUG):
    print_ = print if logger is None else lambda msg: logger.log(level, msg)
    t0 = time.time()
    print_(f'[{name}] start')
    yield
    print_(f'[{name}] done in {time.time() - t0:.1f} s')

# %%
with timer("map"):
    df.datetime.map(jpholiday.is_holiday)
# Out:
# [map] start
# [map] done in 54.4 s

# %%
with timer("make_map"):
    dates = df.datetime.unique()
    date_dict = {}
    for i in dates:
        date_dict[i] = jpholiday.is_holiday(pd.to_datetime(i))
    df.datetime.map(date_dict)
# Out:
# [make_map] start
# [make_map] done in 0.3 s

# %%
jpholiday.is_holiday(df.datetime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-6372991ae442> in <module>
# ----> 1 jpholiday.is_holiday(df.datetime)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/jpholiday/jpholiday.py in is_holiday(date)
#      24     """
#      25     for holiday in registry.RegistryHolder.get_registry():
# ---> 26         if holiday.is_holiday(date):
#      27             return True
#      28
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/jpholiday/registry.py in is_holiday(self, date)
#      32
#      33     def is_holiday(self, date):
# ---> 34         if self._is_holiday(date):
#      35             return True
#      36         else:
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/jpholiday/holiday.py in _is_holiday(self, date)
#      11 class NewYear(registry.BaseHoliday):
#      12     def _is_holiday(self, date):
# ---> 13         if date.month == 1 and date.day == 1:
#      14             return True
#      15         return False
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
import jpholiday
from datetime import date
today = date.today()
print(today)
print(jpholiday.is_holiday(today))
# Out:
# 2020-12-09
# False
